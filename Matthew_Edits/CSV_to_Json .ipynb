# %%
import csv, json
from geojson import Feature, FeatureCollection, Point

# %%
# features = []
# with open('Data/final_map_data.csv', newline='') as csvfile:
#     reader = csv.reader(csvfile, delimiter=',')
#     for year, office, party_simple, mode, votes, countyname, countyfips, canadidatename, state_abbv, statefips, combinedfips, name, lng, lat in reader:
#         lat, lng = map(float, (latitude, longitude))
#         features.append(
#             Feature(
#                 geometry = Point((longitude, latitude)),
#                 properties = {
#                     'year': year,
#                     'temp': temp,
#                     'party_simple': party_simple,
#                     'mode': mode,
#                     'votes': votes,
#                     'countyname': countyname, 
#                     'countyfips': countyfips, 
#                     'canadidatename': candidatename,
#                     'state_abbv': state_abbv,
#                     'statefips': statefips, 
#                     'combinedfips': combinedfips, 
#                     'name': name,
#                     'lng': lng,
#                     'lat': lat
#                 }
#             )
#         )

# collection = FeatureCollection(features)
# with open("GeoObs.json", "w") as f:
#     f.write('%s' % collection)

# %%
 
# Function to convert a CSV to JSON
# Takes the file paths as arguments
def make_json(csvFilePath, jsonFilePath):
     
    # create a dictionary
    data = {}
     
    # Open a csv reader called DictReader
    with open(csvFilePath, encoding='utf-8') as csvf:
        csvReader = csv.DictReader(csvf)
         
        # Convert each row into a dictionary
        # and add it to data
        for rows in csvReader:
             
            # Assuming a column named 'No' to
            # be the primary key
            primarykey = rows['primarykey']
            countyfips = rows['countyfips']
            data[countyfips] = rows
            votes = rows['votes']
            data[votes] = rows
            
            
            
 
    # Open a json writer, and use the json.dumps()
    # function to dump data
    with open(jsonFilePath, 'w', encoding='utf-8') as jsonf:
        jsonf.write(json.dumps(data, indent=4))
         
# Driver Code
 
# computer system
csvFilePath = r'Data/map_data_noprimary.csv'
jsonFilePath = r'Data/final_map_data_w_key.json'
 
# Call the make_json function
make_json(csvFilePath, jsonFilePath)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16564\2130263551.py in <module>
#      37
#      38 # Call the make_json function
# ---> 39 make_json(csvFilePath, jsonFilePath)
#
# ~\AppData\Local\Temp\ipykernel_16564\2130263551.py in make_json(csvFilePath, jsonFilePath)
#      16             # Assuming a column named 'No' to
#      17             # be the primary key
# ---> 18             primarykey = rows['primarykey']
#      19             countyfips = rows['countyfips']
#      20             data[countyfips] = rows
#
# KeyError: 'primarykey'

# %%
# Function to convert a CSV to JSON
# Takes the file paths as arguments
def make_json2(csvFilePath2, jsonFilePath2):
     
    # create a dictionary
    data = {}
     
    # Open a csv reader called DictReader
    with open(csvFilePath, encoding='utf-8') as csvf:
        csvReader = csv.DictReader(csvf)
         
        # Convert each row into a dictionary
        # and add it to data
        for rows in csvReader:
             
            # Assuming a column named 'No' to
            # be the primary key
            primarykey = rows['primarykey']
            countyfips = rows['countyfips']
            data[countyfips] = rows
            votes = rows['votes']
            data[votes] = rows
            
            
            
 
    # Open a json writer, and use the json.dumps()
    # function to dump data
    with open(jsonFilePath2, 'w', encoding='utf-8') as jsonf:
        jsonf.write(json.dumps(data, indent=4))
         
# Driver Code
 
# computer system
csvFilePath2 = r'Data/map_data_noprimary2.csv'
jsonFilePath2 = r'Data/final_map_data_w_key2.json'
 
# Call the make_json function
make_json2(csvFilePath2, jsonFilePath2)
